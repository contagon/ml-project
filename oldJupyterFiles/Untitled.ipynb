# %%
import pandas as pd
import pickle
import numpy as np
# %run userGridSearch.ipynb

# %%
results = pickle.load(open("results.pkl", 'rb'))

# %%
df = pd.DataFrame(results)

# %%
df[~df['param_rdr__n_neighbors'].isnull()]
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         5.674571           0.0        73.943842             0.0
# 1         5.501072           0.0        73.658426             0.0
# 2         5.479643           0.0        73.706439             0.0
# 3         5.486232           0.0        73.778792             0.0
# 4         5.289579           0.0        69.721997             0.0
# ..             ...           ...              ...             ...
# 155       0.017780           0.0         0.000000             0.0
# 156       0.014907           0.0         0.000000             0.0
# 157       0.010353           0.0         0.000000             0.0
# 158       0.010551           0.0         0.000000             0.0
# 159       0.010785           0.0         0.000000             0.0
#
#                                               param_dr param_dr__n_components  \
# 0    TruncatedSVD(algorithm='randomized', n_compone...                     20
# ...
