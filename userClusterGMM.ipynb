# %%
import numpy as np
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.mixture import GaussianMixture 
import matplotlib.pyplot as plt
from scipy import sparse
from itertools import product
from time import time
import seaborn
# %run Helpers.ipynb

# %%
n_components = [10, 20, 40, 60]
data = [U, Uhat]
num_user = X.shape[0]
n_clusters = [10, 40, 80, 100][::-1]
#also should iterate over number of neighbors used

scores = np.zeros((2, 4, 4))
times = np.zeros((2, 4, 4))

user_test = Utest[:,-1].toarray().flatten().astype('int')
user_test_idx = np.arange(0, Utest.shape[0])

# %%
for i, j, k in product(range(len(data)), range(len(n_clusters)), range(len(n_components))):
    temp_score = []
    
    #make pca
    pca_data = TruncatedSVD(n_components=n_components[k]).fit_transform(data[i])
    
    #make and train clusters
    gm = GaussianMixture(n_components=n_clusters[j]).fit(pca_data)
    labels = gm.predict(pca_data)
    
    #get recommended recipes
    for uidx, u in zip(user_test_idx, user_test):
        #set things up
        start = time()
        liked_recipes = Utest[uidx].nonzero()[1][:-1]
        js = np.argwhere(labels==labels[u]).flatten()
        
        #find recipes that are close
        close_recipes = U[js].nonzero()[1]
        #find 5 most common ones
        recommended_recipes = Counter(close_recipes).most_common(5)
        if uidx % 100 == 0:
            print(uidx, end=" ")
        recommended_recipes = [k[0] for k in recommended_recipes]
        
        #save time
        times[i,j,k] += time() - start
        
        #save scores
        temp_score.append( user_score_temp(liked_recipes, recommended_recipes) )

        
    scores[i,j,k] = np.array(temp_score).mean()
    print("\n",i,j,k, scores[i,j,k], times[i,j,k])
    
np.save("results/scores_userClusterGMM.npy", scores)
np.save("results/times_userClusterGMM.npy", times)
# Out:
# 0 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500 5600 5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900 7000 7100 7200 7300 7400 7500 7600 7700 7800 7900 8000 8100 8200 8300 8400 8500 8600 8700 8800 8900 9000 9100 9200 9300 9400 9500 9600 9700 9800 9900 10000 10100 10200 10300 10400 10500 10600 10700 10800 10900 11000 11100 11200 11300 11400 11500 11600 11700 11800 11900 12000 12100 12200 12300 12400 12500 12600 12700 12800 12900 13000 13100 13200 13300 13400 13500 13600
#  0 0 0 9.024297969059315 131.22292304039001
# ...
